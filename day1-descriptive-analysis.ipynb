# %% [markdown]
# ## 마케터를 위한 기초통계
# - 디지털 마케팅 SCHOOL

# %% [markdown]
# ## 박재근
#
# - 데일리 인텔리전스 AI사업기획실 매니저
# - 데이터 사이언스 SCHOOL 코스매니저
# - 1기 수료생
# - 교통/물류학 전공

# %% [markdown]
# - 여기서 먼저 10분정도 흐름잡고 가기, 전체 수업의 개요

# %% [markdown]
# #### 수업의 개요와 흐름잡기
# ## Chapter 1. 통계를 왜 배워야 하는가 ?
# - 통계의 목적
# - 모델링

# %% [markdown]
# #### 수업의 개요와 흐름잡기
# ## Chapter 2. 통계의 언어 배우기
# - 모집단과 표본
# - 모수와 통계량
# - 기술통계와 추론통계
# - 평균과 분산, 표준편차
# - 확률론
#  - 조건부확률과 베이즈정리
#  - 확률변수와 확률분포

# %% [markdown]
# #### 수업의 개요와 흐름잡기
# ## Chapter 3. 분석의 기본 단계 (과정) 알기
# - 표본
# - 통계적 추정
#  - 신뢰도와 신뢰구간
# - 통계적 가설검정
#  - 유의수준과 P-value
# - A/B test
#  - t-test

# %% [markdown]
# #### 수업의 개요와 흐름잡기
# ## Chapter 4. 분석 방법론 (모형) 배우기
# - 상관분석
# - 회귀분석

# %% [markdown]
# ## Chapter 1. 통계를 왜 배워야 하는가 ?

# %% [markdown]
# ## 1.1. 통계의 목적은 무엇인가 ?

# %% [markdown]
# ## Prediction
# - 불확실성을 줄이고, 최대한 정답을 맞춰가는 것 ( 예측하는 것 )

# %% [markdown]
# ## 함께 풀어보아요~

# %% [markdown]
# ### 문제1. 다음 중 실제 부부가 아닌 커플은?
# 1. 원빈 & 이나영
# 2. 안재현 & 구혜선
# 3. 지성 & 이보영
# 4. 김수현 & 전지현
# 5. 주상욱 & 차예련

# %% [markdown]
# #### 답 : 4. 김수현 & 전지현

# %% [markdown]
# ### 문제2. 살수대첩에서 수나라의 30만대군에 맞서 싸워 고구려를 지킨 고구려의 장군 이름은 무엇일까요?
# 1. 이순신
# 2. 연개소문
# 3. 을지문덕
# 4. 계백
# 5. 광개토대왕

# %% [markdown]
# #### 답 : 3. 을지문덕
# <center><img src="http://cp.culturecontent.com/cp0208/data/CP0208207912/SVC/CP0208207912_f00001.JPG", width=300></center>

# %% [markdown]
# - 정답 공개 필요
# - 문제2 다음 넘어가는 슬라이드 필요
# - 정답을 맞추는것이 예측 문제와 같음
# - 이세상엔 100% 정답은 없음 / 모든 것은 항상 확률이 뒤따름

# %% [markdown]
# ### 방금 전 문제를 어떻게 풀었나요?

# %% [markdown]
# ### 문제2. 살수대첩에서 수나라의 30만대군에 맞서 싸워 고구려를 지킨 고구려의 장군 이름은 무엇일까요?
# 1. <del>이순신</del>
# 2. 연개소문
# 3. 을지문덕
# 4. <del>계백</del>
# 5. <del>광개토대왕</del>

# %% [markdown]
# ## 좀 더 현실에 가까운 문제로 ~

# %% [markdown]
# ### 문제3-1. 다음은 우리나라 직장인 1000명의 연차별 월급을 조사한 결과이다. 이 결과를 바탕으로 **6년차**의 월급을 얼마일지 예측해 보아라.
#  1. 220만원
#  2. 250만원
#  3. 280만원
#  4. 310만원

# %%
from sklearn.datasets import make_regression
X, y, c = make_regression(n_samples=1000, n_features=1, bias=1, noise=7, coef=True, random_state=1)

with plt.style.context(("seaborn-white")):
    fig = plt.figure(figsize=(9, 3))
    plt.scatter(1.5*X+3, y+200, s=5, c="r")
    plt.ylim([100, 300])
    plt.xlim([0, 5])
    plt.ylabel("income")
    plt.xlabel("working year")

# %%
plt.show()

# %% [markdown]
# #### 답 :  3. 280만원

# %% [markdown]
# ### 문제3-2. 이 결과를 바탕으로 **6년차**의 월급을 얼마일지 예측해 보아라.
#  1. 270만원
#  2. 275만원
#  3. 280만원
#  4. 285만원

# %%
plt.show()

# %% [markdown]
# #### 답 :  잘 모르겠음

# %% [markdown]
# ### 문제3-3. 이 결과를 바탕으로 **6년차**의 월급을 얼마일지 예측해 보아라. ( 주관식 )
# - 가장 틀릴 확률이 낮은 방향으로 대답해보세요.

# %%
plt.show()

# %% [markdown]
#  - 대답 : **270만원 이상 ~ 280만원 미만일 것이다.**

# %% [markdown]
# ### 문제3-4. 이 결과를 바탕으로 **6년차**의 월급을 얼마일지 예측해 보아라. ( 주관식 2 )
# - 이전 대답에 조금 더 신뢰성을 부여해서 대답해보세요.

# %%
plt.show()

# %% [markdown]
#  - 대답 : **270만원 이상 ~ 280만원 미만일 것이다.** <br> 그리고 정답에 대한 **신뢰도는 약 95% 이다.**

# %% [markdown]
# ### 1.1.1.  통계의 목적
# <br>
# ### Prediction
# - 불확실성을 줄이고, 최대한 정답을 맞춰가는 것 ( 예측하는 것 )

# %% [markdown]
# ### 1.1.2. 통계가 돌아가는 원리
# <br>
# ### 불확실성을 줄이자. 정답에 근접할 가능성을 높이자 !!! ( ⭐️ )
#
# - 우리가 문제의 정답을 맞추기 위해 풀어나가는 사고방식 그대로 통계분석도 똑같은 원리로 작동한다.

# %% [markdown]
# ## 1.2. 모델링
# - 현실의 문제를 데이터 분석 문제로 변환
#  - ***수학적 기호로 Modeling ( ⭐️ )***
#  - ***\+ 수많은 가정들이 포함됨 ( ⭐️ )***

# %% [markdown]
# ## 1.2. 모델링
#
# <center> ** 현실의 모형화 : $y = f(X)$**  </center> <br>
# <center> ⬇︎ </center>
# <center> **예측 모델 : $\hat{y} = \hat{f}(X) = \text{argmax} ~ P(y \vert X_{new}, D, M)$** <center>

# %% [markdown]
# #### 여기서 잠깐!
# ## 앞에서 그동안 ⭐️ 표시 한 내용이 무엇이었나요?

# %% [markdown]
# ### ⭐️ 표시 한 내용이 무엇이었나요?
# - ***불확실성을 줄이자. 정답에 근접할 가능성을 높이자 !!! ( ⭐️ ) ➜ <font color="blue">확률</font>***
# - ***수학적 기호로 Modeling ( ⭐️ ) ➜ <font color="blue">확률분포, 확률모형</font>***
# - ***\+ 수많은 가정들이 포함됨 ( ⭐️ ) ➜ <font color="blue">정규성</font>***

# %% [markdown]
# ## Chapter 2. 통계의 언어 배우기

# %% [markdown]
# ## 모집단과 표본
#
# <img src="./img/population-sample-1.png",  align="left", width=500>
# <img src="./img/population-sample-2.jpeg",  align="right", width=500>

# %% [markdown]
# ## 2.1.  모집단과 표본
# - **모집단 ( Populataion )**
#  - 분석가의 관심 대상이 되는 모든 개체의 집합
#  - 규모가 작을 때에는 모든 개체를 조사 가능 ( 전수조사 )
#  - 그러나 규모가 클 경우, 다 조사하기 힘듦
#  - ex. 대한민국 고등학교 학생들의 키
# - **표본 ( Sample )**
#  - 조사 대상으로 채택된 일부 집합
#  - 모집단의 규모가 큰 경우, 일부 표본을 뽑아 이를 분석
#  - 모집단의 특성을 파악 ( 추측 )
#  - ex. 서울, 부산, 광주, ... 일부 고등학교 학생 5000명의 키

# %% [markdown]
# ## 2.2. 모수와 통계량
# - **모수 ( Parameter )**
#  - 모집단의 특성을 수치로 나타낸 것
#  - 평균, 분산, 표준편차 : $\mu, { \sigma  }^{ 2 }, \sigma$
# - **통계량 ( Statistic )**
#  - 표본의 특성을 수치로 나타낸 것
#  - 평균, 분산, 표준편차 : $\overset { \_ \_  }{ X } ,{ S }^{ 2 },S$
# - 모집단과 표본을 구분하기 위해 기호를 달리하여 사용

# %% [markdown]
# ## 2.3. 기술통계와 추론통계
# - **기술통계학 ( Descriptive Statistics )**
#  - 자료를 정리하고 요약하는 자료특성의 계산과 관련된 통계학
#  - ex. 우리반 평균 시험점수를 알기 위해 학생들 점수를 모아 평균을 구하는 것
# - **추론통계학 ( Inferential Statistics )**
#  - 모집단에서 뽑은 표본을 분석하여 이를 기초로 모집단의 특성을 추론하는 통계학
#  - ex. 우리나라 고등학교 수능모의고사 평균을 알아보기 위해 몇만 명만 표본으로 뽑아 그들의 점수를 바탕으로 전체 평균을 추측하는 것

# %% [markdown]
# ## 2.3. 기술통계와 추론통계
# <center><img src="http://databaser.net/moniwiki/pds/_ed_86_b5_ea_b3_84_ed_95_99_ec_9d_b4_eb_9e_80_eb_ac_b4_ec_97_87_ec_9d_b8_ea_b0_80/statistics.jpg", width=600,></center>

# %% [markdown]
# ## 2.4. 변수 ( 1 )
# <br>
# ### 양적변수 ( quantitative variable, real value )
#
# 수치로 나타낼 수 있는 변수
#  - **이산변수 ( discrete )**
#    - 정숫값을 취한 수 있는 변수
#    - ex. 자녀수, 자동차판매대수, 세션수 등
#  - **연속변수 ( continuous )**
#    - 모든 실수값을 취할 수 있는 변수
#    - ex. 길이, 무게 등

# %% [markdown]
# ## 2.4. 변수 ( 2 )
# <br>
# ### 질적변수 ( qualitative variable, categorical value )
#
# 수치로 나타낼 수 없는 변수
#   - **명목변수 ( nominal )**
#     - ex. 성별, 종교, 출생지, 운동선수 등번호 등
#   - **서열변수 ( ordinal )**
#     - 측정대상 간의 순서를 매기기 위해 사용되는 변수
#     - ex. 성적 A, B, C 등급

# %% [markdown]
# ## 2.5. 자료의 정리 - 도수분포표
#
# 수집된 자료를 적절한 등급(또는 범주)으로 분류하고 각 등급에 해당되는 빈도수 등을 정리한 표
# <center><img src="http://trsketch.dothome.co.kr/_contents/2009curi/images/img900027.png", width=1000></center>

# %% [markdown]
# ## 2.5. 자료의 정리 - 히스토그램
#
# - 도수분포표를 그래프로 나타낸 것
# - 보통 히스토그램에서는 가로축이 계급, 세로축이 도수를 뜻함
#
# <center><img src="https://upload.wikimedia.org/wikipedia/commons/1/1d/Example_histogram.png", width=500></center>

# %% [markdown]
# ### 히스토그램 ( 예제 ) - 문제
# - 질적 자료의 도수분포표 & 히스토그램 작성하기
#  - 아파트 A 에 어떤 직업을 가진 사람들이 얼마나 살고 있는가를 알기 위해서 세대주들의 직업을 조사해 보니 다음과 같았다. 아래 데이터를 이용하여 4개의 직업을 구분한 도수분포표와 히스토그램을 그려라.
# <br>
# <center><img src="./img/example1-histogram1.png", width=1000></center>

# %% [markdown]
# ### 히스토그램 ( 예제 ) - 정답
# <br>
# <center><img src="./img/example1-histogram2.png", width=1000></center>

# %% [markdown]
# ### 히스토그램 ( 실습 ) - GA데이터로 히스토그램 그리기

# %% [markdown]
# ### 히스토그램 ( 실습 ) - 준비단계 ( 1 )
#
# - 데이터 수집
#  - GA접속 - 잠재고객 개요 - 내보내기 - Excel(XLSX)
#  - "DMS실습(1)-히스토그램, 분포특성.xlsx" 로 함께 실습
#
# <center><img src="./img/histogram-0.png", width=1000></center>

# %% [markdown]
# ### 히스토그램 ( 실습 ) - 준비단계 ( 2 )
#
# - 엑셀 **분석도구** 추가하기 ( Windows OS )
#  - 파일 - 옵션 - 추가기능 - 분석도구 클릭
#  - 이동 클릭
#
# <center><img src="./img/histogram-2.png", width=800></center>

# %% [markdown]
# ### 히스토그램 ( 실습 ) - 준비단계 ( 3 )
#
# - 엑셀 **분석도구** 추가하기 ( Window OS )
#  - 추가기능 상자에서 **분석도구** 클릭 - 확인
# - 엑셀 **분석도구** 추가하기 ( Mac OS )
#  - 도구(Tools) - 추가기능(Add-ins) - 분석도구(Analysis ToolPack)
#
# <img src="./img/histogram-3.png", width=400, style="float: left; margin-left: 70px;">
# <img src="./img/histogram-1.png", width=400, style="float: right; margin-right: 70px;">

# %% [markdown]
# ### 히스토그램 ( 실습 ) - 시작
#  - "DMS실습(1)-히스토그램, 분포특성.xlsx" - "Histogram Sheet"
#  - 수업 후 실행한 엑셀 파일 나눠 드릴게요!

# %% [markdown]
# ## 2.6. 분포의 특성 ( 1 ) - 집중화경향
# <br>
# ### 최빈값 ( mode )
# 최빈값은 빈도수가 가장 많이 발생한 관찰값을 말함
# - ex) 1, 3, 6, 6, 6, 7, 7, 12, 12, 19 있을때, 최빈값은 6이다.
#
# <br>
# ### 중앙값 ( median )
# 중앙값은 수치로 된 자료를 크기순서대로 나열할 때, 가장 가운데에 위치하는 관찰값을 말한다.
# - ex) 1, 2, 4, 5, 7, 9, 10 있을때, 중앙값은 5이다.

# %% [markdown]
# ## 2.6. 분포의 특성 ( 1 ) - 집중화경향
# <br>
# ### 산술평균 ( arithmetic mean )
# 우리가 흔히 사용하는 간단한 평균, 그냥 "평균" 이라고도 한다.
#
# $$\bar{X} = \frac{X_1 + X_2 + \cdots + X_n}{n} = \frac{\sum X_i}{n} $$
#
# <br>
# ### 가중평균 ( weighted arithmetic mean )
# 같은 모집단에서 표본을 서로 다른 개수로 뽑은 경우 (가중치가 존재하는 경우) 평균값을 구할때 사용
#
# $$\bar{X} = \frac{n_1 X_1 + n_2 X_2 + \cdots + n_k X_k}{n_1 + n_2 + \cdots + n_k} = \frac{\sum n_i X_i}{\sum n_i} $$

# %% [markdown]
# ### 평균과 최빈값, 중앙값 위치 비교
# - 대칭분포
#  - 평균 = 중앙값 = 최빈값 모두 같다
# - 왼쪽꼬리분포 ( skewed to the left )
#  - 평균은 중앙값보다 작다
# - 오른쪽꼬리분포 ( skewed to the right )
#  - 평균은 중앙값보다 크다
# <img src="http://webbuild1.knu.ac.kr/~bskim/image/skew2.jpg", width=800>

# %% [markdown]
# ## 2.6. 분포의 특성 ( 2 ) - 흩어진 정도
# <br>
# ### 분산 ( variance )
# 자료가 평균으로부터 얼마나 떨어져 분포하는지를 가늠하는 숫자 <br />
# 분산이란 각각의 관찰값에 대한 평균과의 편차를 제곱하여 그 평균을 구한 것
#
# - 모집단의 분산 ( ${ \sigma  }^{ 2 }$ )
# - 표본의 분산 ( ${S}^2$)
#   - $n$ 대신 $(n-1)$을 나누는 이유는, $(n-1)$을 나누어줌으로써 모집단의 $\sigma$를 추정하는데 더 적절한 표준편차를 구하기 위함이다.
#
# <center><img src="http://www.safetygo.com/xe/files/attach/images/384/602/013/02df6495492411476f5dd9608a8718f6.gif", width=700,></center>

# %% [markdown]
# ## 2.6. 분포의 특성 ( 2 ) - 흩어진 정도
# <br>
# ### 표준편차 ( standard deviation )
# 분산의 양의 제곱근
#
# - 모집단의 표준편차 ( $\sigma = \sqrt{\sigma ^2}$ )
# - 표본의 표준편차 ( $S = \sqrt{S ^2}$ )

# %% [markdown]
# ### 분포의 특성 ( 실습 )
# - 전체 세션의 평균과 분산, 표준편차 등을 구해보자 ( 기술통계 )
# - "DMS실습(1)-히스토그램, 분포특성.xlsx" - "Descriptive Sheet"

# %% [markdown]
# - 우리가 특성 값을 구하는건 분포를 이해하기 위함임
# - 분포 그림에서 평균, 분산, 왜도가 의미하는 바를 알려주기
# - 우리가 지금 하는 건 기술통계
# - GA 는 기술통계
# - 기술통계의 목적은 데이터를 잘 정리하는 것, 여러 기준으로 정리할 수 있음, 도수분포표, 히스토그램, 분포 등
# - 분포로 정리하는 건 한눈에 보기 편하기 때문에 자주 사용

# %% [markdown]
# ## 2.7. 확률론
# - 확률( probability )이란 어떤 상황이 발생할 가능성

# %% [markdown]
# ## 2.7.1. 집합이론
# - 확률이론을 쉽게 설명하기 위해서는 집합이론의 용어와 부호 사용하는 것이 편리
# - 집합 ( set ) 이란 개체 또는 원소 ( element )의 모임이라 정의
# - 원소는 { ... } 속에 넣는 것이 관례
#  - ex. A = { 남자, 여자 }, B = { 10대, 20대, 30대, ... }

# %% [markdown]
# **1. 여집합**
# -  $A^C$ = { 전체집합 중에서 집합 A 에 포함되지 않는 원소들 }
# <center><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b9/SetComplement.svg/400px-SetComplement.svg.png", width=300></center>
#
# **2. 합집합**
# -  $A \cup B$ = { 집합 A 또는 집합 B에 속하는 원소  }
# <center><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/32/SetUnion.svg/500px-SetUnion.svg.png", width=300></center>

# %% [markdown]
# **3. 교집합**
# -  $A \cap B$ = { 집합 A와 B의 공통 원소  }
# <center><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/cb/SetIntersection.svg/500px-SetIntersection.svg.png", width=300></center>
#
# **합집합의 계산**
# - $ A \cup B = A + B - A \cap B $
#  - if) 집합 $A$와 $B$가 서로 배타적( mutually exclusive )일 때 <br>( $A \cap B = \emptyset$ )
#  - $ A \cup B = A + B $

# %% [markdown]
# ### 집합이론 ( 예제 ) - 문제
# - 100명의 학생이 시험을 본 결과, 영어시험에서 60점 이상 받은 학생은 40명, 국어시험에서 60점 이상 받은 학생이 50명이었다. 영어시험과 국어시험 모두 60점 이상 받은 학생이 15명이라면, 최소한 한 과목에서 60점 이상을 받은 학생은 몇명인가?

# %% [markdown]
# ### 집합이론 ( 예제 ) - 정답
# - $A$ : 영어시험에서 60점 이상 받은 사건
# - $B$ : 국어시험에서 60점 이상 받은 사건
# - 정답 :
# $$
# \begin{align}
# A \cup B &= A + B - A \cap B \\
# &= 40 + 50 - 15 \\
# & = 75 (명)
# \end{align}
# $$

# %% [markdown]
# ## 2.7.2.  확률법칙 ( 1 )
# <br>
# ### 덧셈법칙
# - 집합이론에서 합집합의 개념
# - $ P(A \cup B) = P(A) + P(B) - P(A \cap B) $
#  - if) A사건과 B사건이 서로 배타적일 때 ( 서로 독립일 때 )
#  - $ P(A \cup B) = P(A) + P(B) $

# %% [markdown]
# ## 2.7.2. 확률법칙 ( 2 )
# <br>
# ### 조건부확률
# - 사건 B가 발생했다는 조건하에서 사건 A가 발생할 확률
# $$P(A \vert B) = \frac{P(A \cap B)}{P(B)}$$
#
#
# - *조건부확률은 표본공간이 전체사건이 되는 것이 아니라, 새로운 조건이 부여되어 관심대상이 **새로운 표본공간**이 되는 경우에 쓰이는 개념이다.*

# %% [markdown]
# ### 조건부확률 ( 예제 ) - 문제
# - 패스트캠퍼스 스쿨 수강생 200명 중에서 여자 수강생은 40명이다. 30명이 디지털 마케팅 수강생이며, 이 중 여자 수강생은 10명이다. 다음 조건부 확률을 구해보자.
#
#
# 1. 여자 수강생 중에서 디지털 마케팅 수강생의 구성은 어떻게 되는가?
# 2. 디지털 마케팅 수강생 중에서 여자 수강생의 구성은 어떻게 되는가?

# %% [markdown]
# ### 조건부확률 ( 예제 ) - 정답
#
# ![](./img/example-cond-prob.png)
#
# 1. 여자 수강생 중에서 디지털 마케팅 수강생의 구성은 어떻게 되는가?
# $$P(DMS \vert 여자) = \frac{DMS \cap 여자}{여자} = \frac{10}{40} = 0.25$$
#
# 2. 디지털 마케팅 수강생 중에서 여자 수강생의 구성은 어떻게 되는가?
# $$P(여자 \vert DMS) = \frac{DMS \cap 여자}{DMS} = \frac{10}{30} = 0.33$$

# %% [markdown]
# ### 조건부확률 ( 실습 ) - 인구통계 GA 데이터로 조건부확률 구하기

# %% [markdown]
# ### 조건부확률 ( 실습 ) - 1. 목표 설정하기
# - 성별에 따라 재방문 할 확률은 어떻게 될까?
# - 성별에 따라 이탈률은 달라질까?
# - 성별에 따른 모바일 접속자 비율은 어떻게 될까?

# %% [markdown]
# ### 조건부확률 ( 실습 ) - 2. 데이터 수집
#
# - GA접속 - 잠재고객 - 인구통계
# - 세그먼트 추가 ( 재사용자, 이탈한 세션수, 모바일 트래픽 )
# - 내보내기 - Excel(XLSX)
# - "DMS실습(2)-조건부확률.xlsx" 로 함께 실습

# %% [markdown]
# ### 조건부확률 ( 실습 ) - 3. 데이터 탐색 및 확률 구하기
# - 수업 후 실행한 엑셀 파일 나눠 드릴게요!

# %% [markdown]
# ## 수업끝 - HOMEWORK
# - 아래 스프레드시트 파일을 복사하여 개인 드라이브에서 작업하시면 됩니다. (작업시트에서 과제 진행)
# - 기술통계, 히스토그램 과제링크 : https://goo.gl/Rtpk44
#  - 과제 목표 : 각 연령별 사용자를 히스토그램을 활용하여 시각화하고, 적절한 기술통계량을 사용하여 분포를 설명해보세요.
# - 조건부확률 과제 : https://goo.gl/P5d7eh
#  - 과제 목표 : 성별에 따른 각 기기별(모바일, 데스크탑, 태블릿) 세션의 (조건부)확률을 구하고, 결과를 도출하세요.

# %% [markdown]
# - 조건부확률 과제1 : https://goo.gl/9eQCpb
#  - 과제 목표 : 성별에 따른 각 사용자 유형별(신규, 재사용자, 이탈) 세션의 (조건부)확률을 구하고, 결과를 도출하세요.
